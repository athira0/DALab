# %%
import numpy as np
import pandas as pd

# %%
uberdata=pd.read_csv('/Users/athirakumar/Documents/MyUberDrives.csv')
df = pd.DataFrame(uberdata)
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.mean()
# Out:
# MILES*    21.115398
# RATING     2.600346
# dtype: float64

# %%
df.loc[:,"MILES*"].mean()
# Out:
# 21.115397923875435

# %%
df.median()
# Out:
# MILES*    6.0
# RATING    3.0
# dtype: float64

# %%
df.mode()
# Out:
#        START_DATE*        END_DATE* CATEGORY* START* STOP*  MILES* PURPOSE*  \
# 0  6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary     9.9  Meeting
#
#    RATING
# 0       3

# %%
import matplotlib.pyplot as plt

# %%
import scipy

# %%
from scipy import stats

# %%
scipy.stats.gmean(df.loc[:,"MILES*"])
# Out:
# 5.802617565816041

# %%
scipy.stats.hmean(df.loc[:,"MILES*"])
# Out:
# 3.71060988177663

# %%
scipy.stats.iqr(df.loc[:,"RATING"])
# Out:
# 3.0

# %%
scipy.stats.iqr(df.loc[:,"MILES*"])
# Out:
# 7.5

# %%
ax1 = df.plot.scatter(x='MILES*',
...                       y='RATING',
...                       c='DarkBlue')

# %%
bp=df.boxplot(column=["MILES*","RATING"])

# %%
df.hist(column="RATING")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a18838e10>]],
#       dtype=object)

# %%
df.hist(column=["RATING","MILES*"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a18939fd0>,
# ...
#       dtype=object)

# %%
df.plot.bar(x="CATEGORY*",y="RATING",rot=0)

# %%
plot = df.plot.pie(y='CATEGORY*', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-c5101202e38e> in <module>
# ----> 1 plot = df.plot.pie(y='CATEGORY*', figsize=(5, 5))
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in pie(self, y, **kwds)
#    3433             >>> plot = df.plot.pie(subplots=True, figsize=(6, 3))
#    3434         """
# -> 3435         return self(kind='pie', y=y, **kwds)
#    3436
#    3437     def scatter(self, x, y, s=None, c=None, **kwds):
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
# ...

# %%
plot = df.plot.pie(y='RATING', figsize=(5, 5))

# %%
plot = df.plot.pie(x="CATEGORY", y='RATING', figsize=(5, 5))

# %%
ppp = df.plot.pie(y='RATING', figsize=(5, 5))
