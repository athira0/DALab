# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
uberdata=pd.read_csv("MyUberDrives.csv")
df=pd.DataFrame(uberdata)

# %%
ax1=df.plot.scatter(x='MILES*',y='REST_STOPS')

# %%
ax1=df.plot.scatter(x='MILES*',y='REST_STOPS',marker='o')

# %%
ax1=df.plot.scatter(x='MILES*',y='REST_STOPS',c="Purple",marker='o')
plot.xlim(0,250)
plot.ylim(0,250)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8e95fe67952f> in <module>()
#       1 ax1=df.plot.scatter(x='MILES*',y='REST_STOPS',c="Purple",marker='o')
# ----> 2 plot.xlim(0,250)
#       3 plot.ylim(0,250)
#
# NameError: name 'plot' is not defined

# %%
ax1=df.plot.scatter(x='MILES*',y='REST_STOPS',c="Purple",marker='o')
plt.xlim(0,250)
plt.ylim(0,250)
# Out:
# (0, 250)

# %%
ax1=df.plot.scatter(x='MILES*',y='REST_STOPS',c="Purple",marker='o')
plt.xlim(0,150)
plt.ylim(0,250)
# Out:
# (0, 250)

# %%
from scikit-image import io
# Out:
#   File "<ipython-input-17-1b46719cedb6>", line 1
#     from scikit-image import io
#                ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
img=plt.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img=plt.imread('image.jpg')
plt.show()

# %%
import matplotlib.image as mpimg

# %%
img= mpimg.imread('image.jpg')
imgplot=plt.imshow(img)

# %%
img.shape
# Out:
# (100, 100, 4)

# %%
print(np.mean(img))
# Out:
# 139.71375

# %%
print(np.std(img))
# Out:
# 123.82612047115705

# %%
plt.imshow(img[:,:,0].T)

# %%
plt.imshow(img[25:65, 20:80])

# %%
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
plt.plot(df['MILES*'],df['REST_STOPS'])
plt.plot(df['MILES*'],df['RATING'])
plt.xlabel('Miles')
plt.ylabel('Rest stops')
plt.show()

# %%
plt.plot(df['MILES*'],df['REST_STOPS'])
plt.scatter(df['MILES*'],df['RATING'])
plt.xlabel('Miles')
plt.ylabel('Rest stops')
plt.show()

# %%
plt.plot(df['MILES*'],df['REST_STOPS'],'k',
         df['MILES*'],df['RATING'],'g')
plt.xlabel('Miles')
plt.ylabel('Rest stops')
plt.axis([-10,350,-10,300])
plt.show()
